# %% [markdown]
# # Automobile price prediction

# %% [markdown]
# data source: https://www.kaggle.com/datasets/toramky/automobile-dataset

# %%
# import required liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math as m
import random
# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')
import sys
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Load data

# %%
data = pd.read_csv(r'Automobile_data.csv')

# %%
# print 2 rows
data.head(2)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111      5000       21
# 1         mpfi  3.47    2.68               9.0        111      5000       21
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
#
# [2 rows x 26 columns]

# %%
# print all atributes
data.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               205 non-null    object
#  19  stroke             205 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         205 non-null    object
#  22  peak-rpm           205 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              205 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %% [markdown]
# ### Observations:
# 1) Total 205 data points and 26 attributes.
#
# 2) Attributes has different data types.
#
# 3) Here shows no NaN values, but some attributes filled with '?' instead of NaN. we will try to fill these NaN values in data preprocessing.

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Convert '?'  to NaN

# %%
data.replace('?', np.nan, inplace = True)

# %% [markdown]
# ### Get all missing values

# %%
missing_data = data.isnull()
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# symboling
# False    205
# Name: symboling, dtype: int64
#
# normalized-losses
# False    164
# True      41
# Name: normalized-losses, dtype: int64
#
# make
# False    205
# Name: make, dtype: int64
#
# fuel-type
# False    205
# Name: fuel-type, dtype: int64
#
# aspiration
# False    205
# Name: aspiration, dtype: int64
#
# num-of-doors
# False    203
# True       2
# Name: num-of-doors, dtype: int64
#
# body-style
# False    205
# Name: body-style, dtype: int64
#
# drive-wheels
# False    205
# Name: drive-wheels, dtype: int64
#
# engine-location
# False    205
# Name: engine-location, dtype: int64
#
# wheel-base
# False    205
# Name: wheel-base, dtype: int64
#
# length
# False    205
# Name: length, dtype: int64
#
# width
# False    205
# Name: width, dtype: int64
#
# height
# False    205
# Name: height, dtype: int64
#
# curb-weight
# False    205
# Name: curb-weight, dtype: int64
#
# engine-type
# False    205
# Name: engine-type, dtype: int64
#
# num-of-cylinders
# False    205
# Name: num-of-cylinders, dtype: int64
#
# engine-size
# False    205
# Name: engine-size, dtype: int64
#
# fuel-system
# False    205
# Name: fuel-system, dtype: int64
#
# bore
# False    201
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    201
# True       4
# Name: stroke, dtype: int64
#
# compression-ratio
# False    205
# Name: compression-ratio, dtype: int64
#
# horsepower
# False    203
# True       2
# Name: horsepower, dtype: int64
#
# peak-rpm
# False    203
# True       2
# Name: peak-rpm, dtype: int64
#
# city-mpg
# False    205
# Name: city-mpg, dtype: int64
#
# highway-mpg
# False    205
# Name: highway-mpg, dtype: int64
#
# price
# False    201
# True       4
# Name: price, dtype: int64

# %% [markdown]
# Based on the summary above, following columns has missing values:
#
# 1) "normalized-losses": 41 missing data
#
# 2) "num-of-doors": 2 missing data
#
# 3) "bore": 4 missing data
#
# 4) "stroke" : 4 missing data
#
# 5) "horsepower": 2 missing data
#
# 6) "peak-rpm": 2 missing data
#
# 7) "price": 4 missing data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak-rpm           203 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %% [markdown]
# ### Convert object data types into numerical

# %% [markdown]
# In some columns missing values filled with '?', that's why some numerical columns was converted into object type. We will again convert it to numerical.

# %%
data['normalized-losses']=data['normalized-losses'].astype(float)
data['bore']=data['bore'].astype(float)
data['stroke']=data['stroke'].astype(float)
data['horsepower']=data['horsepower'].astype(float)
data['peak-rpm']=data['peak-rpm'].astype(float)
data['price']=data['price'].astype(float)

# %% [markdown]
# ### Fill missing values in "number of doors" column

# %%
data[data['num-of-doors'].isnull()]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 27          1              148.0  dodge       gas      turbo          NaN
# 63          0                NaN  mazda    diesel        std          NaN
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 27      sedan          fwd           front        93.7  ...           98
# 63      sedan          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 27         mpfi  3.03    3.39               7.6      102.0    5500.0       24
# 63          idi  3.39    3.39              22.7       64.0    4650.0       36
#
#     highway-mpg    price
# 27           30   8558.0
# 63           42  10795.0
#
# [2 rows x 26 columns]

# %% [markdown]
# Here we are not using mean, mode, median or most frequent value imputation techniques, because "number of doors" attribute depends on other attributes. It mostly depends on body style and make of the vehicle.

# %%
# get all data points having sedan body style and dodge and mazda make.
data[(data['body-style']=='sedan')  & ((data['make']=='dodge') | (data['make']=='mazda'))]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 25          1              148.0  dodge       gas        std         four
# 26          1              148.0  dodge       gas        std         four
# 27          1              148.0  dodge       gas      turbo          NaN
# 53          1              113.0  mazda       gas        std         four
# 54          1              113.0  mazda       gas        std         four
# 60          0              115.0  mazda       gas        std         four
# 62          0              115.0  mazda       gas        std         four
# 63          0                NaN  mazda    diesel        std          NaN
# 65          0              118.0  mazda       gas        std         four
# 66          0                NaN  mazda    diesel        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 25      sedan          fwd           front        93.7  ...           90
# 26      sedan          fwd           front        93.7  ...           90
# 27      sedan          fwd           front        93.7  ...           98
# 53      sedan          fwd           front        93.1  ...           91
# 54      sedan          fwd           front        93.1  ...           91
# 60      sedan          fwd           front        98.8  ...          122
# 62      sedan          fwd           front        98.8  ...          122
# 63      sedan          fwd           front        98.8  ...          122
# 65      sedan          rwd           front       104.9  ...          140
# 66      sedan          rwd           front       104.9  ...          134
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 25         2bbl  2.97    3.23               9.4       68.0    5500.0       31
# 26         2bbl  2.97    3.23               9.4       68.0    5500.0       31
# 27         mpfi  3.03    3.39               7.6      102.0    5500.0       24
# 53         2bbl  3.03    3.15               9.0       68.0    5000.0       31
# 54         2bbl  3.08    3.15               9.0       68.0    5000.0       31
# 60         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 62         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 63          idi  3.39    3.39              22.7       64.0    4650.0       36
# 65         mpfi  3.76    3.16               8.0      120.0    5000.0       19
# 66          idi  3.43    3.64              22.0       72.0    4200.0       31
#
#     highway-mpg    price
# 25           38   6692.0
# 26           38   7609.0
# 27           30   8558.0
# 53           38   6695.0
# 54           38   7395.0
# 60           32   8495.0
# 62           32  10245.0
# 63           42  10795.0
# 65           27  18280.0
# 66           39  18344.0
#
# [10 rows x 26 columns]

# %% [markdown]
# From above observation we can conclude that dodge and mazda make and sedan body style vehicles has 4 number of doors.

# %%
#replace the missing 'num-of-doors' values by 'four' 
data["num-of-doors"].replace(np.nan, "four", inplace=True)

# %% [markdown]
# ### Fill missing values in "horsepower" column

# %%
# get all rows with null values in 'horsepower' column
data[data['horsepower'].isnull()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 130          0                NaN  renault       gas        std         four
# 131          2                NaN  renault       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 130      wagon          fwd           front        96.1  ...          132
# 131  hatchback          fwd           front        96.1  ...          132
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 130         mpfi  3.46     3.9               8.7        NaN       NaN
# 131         mpfi  3.46     3.9               8.7        NaN       NaN
#
#     city-mpg  highway-mpg   price
# 130       23           31  9295.0
# 131       23           31  9895.0
#
# [2 rows x 26 columns]

# %%
# check correlation with other numerical attributes
data[data.columns[1:]].corr()['horsepower'][:-1]
# Out:
# normalized-losses    0.295772
# wheel-base           0.352297
# length               0.555003
# width                0.642482
# height              -0.110711
# curb-weight          0.751034
# engine-size          0.810773
# bore                 0.577273
# stroke               0.090254
# compression-ratio   -0.205874
# horsepower           1.000000
# peak-rpm             0.130971
# city-mpg            -0.803620
# highway-mpg         -0.770908
# Name: horsepower, dtype: float64

# %%
# plot scatter plot to check correlation between engine size and horsepower
plt.figure(figsize = (5,5))
sns.scatterplot(x = 'horsepower', y = 'engine-size', data = data)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='engine-size'>

# %% [markdown]
# Enigine size is highly correlated with horsepower. We can use this attribute for imputation.
#
# For NaN values in "horsepower", engine size is 132, so we will use range between 127 and 137.

# %%
data[(data['engine-size'] > 127) & (data['engine-size'] < 137)]
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1                NaN         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0                NaN         audi       gas      turbo
# 66           0                NaN        mazda    diesel        std
# 117          0              161.0       peugot       gas      turbo
# 130          0                NaN      renault       gas        std
# 131          2                NaN      renault       gas        std
# 191          0                NaN   volkswagen       gas        std
# 198         -2              103.0        volvo       gas      turbo
# 199         -1               74.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 4           four        sedan          4wd           front        99.4  ...
# 5            two        sedan          fwd           front        99.8  ...
# 6           four        sedan          fwd           front       105.8  ...
# 7           four        wagon          fwd           front       105.8  ...
# 8           four        sedan          fwd           front       105.8  ...
# 9            two    hatchback          4wd           front        99.5  ...
# 66          four        sedan          rwd           front       104.9  ...
# 117         four        sedan          rwd           front       108.0  ...
# 130         four        wagon          fwd           front        96.1  ...
# 131          two    hatchback          fwd           front        96.1  ...
# 191         four        sedan          fwd           front       100.4  ...
# 198         four        sedan          rwd           front       104.3  ...
# 199         four        wagon          rwd           front       104.3  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            130         mpfi  3.47    2.68               9.0      111.0
# 4            136         mpfi  3.19    3.40               8.0      115.0
# 5            136         mpfi  3.19    3.40               8.5      110.0
# 6            136         mpfi  3.19    3.40               8.5      110.0
# 7            136         mpfi  3.19    3.40               8.5      110.0
# 8            131         mpfi  3.13    3.40               8.3      140.0
# 9            131         mpfi  3.13    3.40               7.0      160.0
# 66           134          idi  3.43    3.64              22.0       72.0
# 117          134         mpfi  3.61    3.21               7.0      142.0
# 130          132         mpfi  3.46    3.90               8.7        NaN
# 131          132         mpfi  3.46    3.90               8.7        NaN
# 191          136         mpfi  3.19    3.40               8.5      110.0
# 198          130         mpfi  3.62    3.15               7.5      162.0
# 199          130         mpfi  3.62    3.15               7.5      162.0
#
#      peak-rpm city-mpg  highway-mpg    price
# 0      5000.0       21           27  13495.0
# 1      5000.0       21           27  16500.0
# 4      5500.0       18           22  17450.0
# 5      5500.0       19           25  15250.0
# 6      5500.0       19           25  17710.0
# 7      5500.0       19           25  18920.0
# 8      5500.0       17           20  23875.0
# 9      5500.0       16           22      NaN
# 66     4200.0       31           39  18344.0
# 117    5600.0       18           24  18150.0
# 130       NaN       23           31   9295.0
# 131       NaN       23           31   9895.0
# 191    5500.0       19           24  13295.0
# 198    5100.0       17           22  18420.0
# 199    5100.0       17           22  18950.0
#
# [15 rows x 26 columns]

# %% [markdown]
# For given range of engine size, horsepower is between range 72 to 162. This is huge difference, when we consider horsepower variance. Let's check which other attributes affect "horsepower".

# %%
features = ["aspiration","fuel-type"]
plt.figure(figsize = (10,5))
for i in enumerate (features):
    plt.subplot(1,2,i[0]+1)
    sns.boxplot(x = i[1],y = 'horsepower',data = data)

# %% [markdown]
# I have observed that this difference occure due to "aspiration" attribute, when we have std we got horsepower range between 72 to 115 and when we have terbo we got horsepower range between 140 to 162. Again horsepower affected by fuel type, for diesel we got very low horsepower = 72.

# %%
data[((data['fuel-type'] == 'gas') & (data['aspiration'] == 'std')) & ((data['engine-size'] > 127) & (data['engine-size'] < 137))]
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 4            2              164.0         audi       gas        std
# 5            2                NaN         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1                NaN         audi       gas        std
# 130          0                NaN      renault       gas        std
# 131          2                NaN      renault       gas        std
# 191          0                NaN   volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 4           four        sedan          4wd           front        99.4  ...
# 5            two        sedan          fwd           front        99.8  ...
# 6           four        sedan          fwd           front       105.8  ...
# 7           four        wagon          fwd           front       105.8  ...
# 130         four        wagon          fwd           front        96.1  ...
# 131          two    hatchback          fwd           front        96.1  ...
# 191         four        sedan          fwd           front       100.4  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            130         mpfi  3.47    2.68               9.0      111.0
# 4            136         mpfi  3.19    3.40               8.0      115.0
# 5            136         mpfi  3.19    3.40               8.5      110.0
# 6            136         mpfi  3.19    3.40               8.5      110.0
# 7            136         mpfi  3.19    3.40               8.5      110.0
# 130          132         mpfi  3.46    3.90               8.7        NaN
# 131          132         mpfi  3.46    3.90               8.7        NaN
# 191          136         mpfi  3.19    3.40               8.5      110.0
#
#      peak-rpm city-mpg  highway-mpg    price
# 0      5000.0       21           27  13495.0
# 1      5000.0       21           27  16500.0
# 4      5500.0       18           22  17450.0
# 5      5500.0       19           25  15250.0
# 6      5500.0       19           25  17710.0
# 7      5500.0       19           25  18920.0
# 130       NaN       23           31   9295.0
# 131       NaN       23           31   9895.0
# 191    5500.0       19           24  13295.0
#
# [9 rows x 26 columns]

# %% [markdown]
# Now, for NaN values we have fuel type = gas, aspiration = std and engine size between 127 to 137, we have horsepower between 110 to 115. from observations we can impute NaN values with values between 110 to 115

# %%
# from above observations replacing missing value with 112
data["horsepower"].replace(np.nan, 112, inplace=True)

# %% [markdown]
# ### Fill missing values in "peak-rpm" column

# %%
# Get all rows with null values in 'peak-rpm' column
data[data['peak-rpm'].isnull()]
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 130          0                NaN  renault       gas        std         four
# 131          2                NaN  renault       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 130      wagon          fwd           front        96.1  ...          132
# 131  hatchback          fwd           front        96.1  ...          132
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 130         mpfi  3.46     3.9               8.7      112.0       NaN
# 131         mpfi  3.46     3.9               8.7      112.0       NaN
#
#     city-mpg  highway-mpg   price
# 130       23           31  9295.0
# 131       23           31  9895.0
#
# [2 rows x 26 columns]

# %%
data.iloc[130:132, 10:16]
# Out:
#      length  width  height  curb-weight engine-type num-of-cylinders
# 130   181.5   66.5    55.2         2579         ohc             four
# 131   176.8   66.6    50.5         2460         ohc             four

# %%
# check correlation with other numerical attributes
data[data.columns[1:]].corr()['peak-rpm'][:-1]
# Out:
# normalized-losses    0.264597
# wheel-base          -0.361052
# length              -0.287325
# width               -0.219957
# height              -0.322272
# curb-weight         -0.266306
# engine-size         -0.244618
# bore                -0.264269
# stroke              -0.071493
# compression-ratio   -0.436221
# horsepower           0.130971
# peak-rpm             1.000000
# city-mpg            -0.113788
# highway-mpg         -0.054257
# Name: peak-rpm, dtype: float64

# %% [markdown]
# Numerical columns are not correlated with peak-rpm, therefore we can't use for prediction NaN value in peak-rpm attribute. Let's check what relation we can find with categorical attributes.

# %%
features = ["fuel-type","aspiration","drive-wheels","engine-location","engine-type","num-of-cylinders","fuel-system",]
plt.figure(figsize = (15,10))
for i in enumerate (features):
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(x = i[1],y = 'peak-rpm',data = data)

# %% [markdown]
# 1) peak rpm has only 2 missing values.
#
# 2) Above 7 caterorical attributes are same for both missing values,using these 7 attributes, it would be easy for imputation.
#
# 3) From above observation missing values would be between range 4800 to 5500. We will impute NaN value between given range by using    mode. We are using mode because peak rpm attribute is a categorical attribute.

# %%
# create dataframe by using above attributes and given range
nan_peak_rpm = data[(data['peak-rpm'] >= 4800) & (data['peak-rpm'] <= 5500) & (data['fuel-system'] == 'mpfi') & (data['engine-location'] == 'front') & (data['drive-wheels'] == 'rwd') & (data['aspiration'] == 'std') & (data['fuel-type'] == 'gas') & (data['engine-type'] == 'ohc') & (data['num-of-cylinders'] == 'four')]

# %%
# getting mean based on above conditions
nan_peak_rpm['peak-rpm'].mean()
# Out:
# 5100.0

# %%
# from above observations replacing missing value with 5100
data["peak-rpm"].replace(np.nan, 5100, inplace=True)

# %% [markdown]
# ### Fill missing values in "bore" column

# %%
# get all rows with null values in 'bore' column
data[data['bore'].isnull()]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 55          3              150.0  mazda       gas        std          two
# 56          3              150.0  mazda       gas        std          two
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           70
# 58  hatchback          rwd           front        95.3  ...           80
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 55         4bbl   NaN     NaN               9.4      101.0    6000.0       17
# 56         4bbl   NaN     NaN               9.4      101.0    6000.0       17
# 57         4bbl   NaN     NaN               9.4      101.0    6000.0       17
# 58         mpfi   NaN     NaN               9.4      135.0    6000.0       16
#
#     highway-mpg    price
# 55           23  10945.0
# 56           23  11845.0
# 57           23  13645.0
# 58           23  15645.0
#
# [4 rows x 26 columns]

# %%
data.iloc[55:59, 10:16]
# Out:
#     length  width  height  curb-weight engine-type num-of-cylinders
# 55   169.0   65.7    49.6         2380       rotor              two
# 56   169.0   65.7    49.6         2380       rotor              two
# 57   169.0   65.7    49.6         2385       rotor              two
# 58   169.0   65.7    49.6         2500       rotor              two

# %%
data['engine-type'].value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: engine-type, dtype: int64

# %% [markdown]
# 1) Here, for all engine type = rotor has NaN values for "bore" attributes.
#
# 2) Using domain knowledge,for rotary engine we don't have any bore and stroke, that's why for we got these attributes with NaN values. But keeping these attributes with NaN values is not a good idea. By using other attributes we will impute these values.
#
# 3) Index 55, 56, 57 are exactly same, only difference in price. But according to our data, there should be no price difference if all other attributes are same. We need to remove these duplicate entries.

# %%
# droping duplicates
data.drop([55,56], axis=0, inplace=True)

# %%
# check correlation with other numerical attributes
data[data.columns[1:]].corr()['bore'][:-1]
# Out:
# normalized-losses   -0.036167
# wheel-base           0.490378
# length               0.607480
# width                0.559204
# height               0.176195
# curb-weight          0.649045
# engine-size          0.594090
# bore                 1.000000
# stroke              -0.055909
# compression-ratio    0.005203
# horsepower           0.577439
# peak-rpm            -0.264045
# city-mpg            -0.594584
# highway-mpg         -0.594572
# Name: bore, dtype: float64

# %% [markdown]
# Numerical columns are less correlated with "bore". Let's check what relation we can find with categorical attributes. If categorical attributes are usefull then we will use it otherwise we will go for numerical categories for imputing missing values.

# %%
features = ["fuel-type","aspiration","drive-wheels","engine-location","engine-type","num-of-cylinders","fuel-system",]
plt.figure(figsize = (15,10))
for i in enumerate (features):
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(x = i[1],y = 'bore',data = data)

# %%
sns.catplot(y="make", x="bore", kind="box", data=data)

# %% [markdown]
# 1) By observing above plots and corrosponding values of other attributes, we can conclude that, missing values will be between 3.3 to 3.65.
#
# 2) We will impute missing value between given range by using mode. We are using mode because bore attribute is a categorical attribute. If we used average value here then it will create one more category and the difference between mean and mode here is very less.

# %%
# create dataframe by using above attributes and given range
nan_bore = data[(data['bore'] >= 3.3) & (data['bore'] <= 3.65)& (data['make']=='mazda')]
nan_bore
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 59          1              129.0  mazda       gas        std          two
# 60          0              115.0  mazda       gas        std         four
# 61          1              129.0  mazda       gas        std          two
# 62          0              115.0  mazda       gas        std         four
# 63          0                NaN  mazda    diesel        std         four
# 64          0              115.0  mazda       gas        std         four
# 66          0                NaN  mazda    diesel        std         four
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 59  hatchback          fwd           front        98.8  ...          122
# 60      sedan          fwd           front        98.8  ...          122
# 61  hatchback          fwd           front        98.8  ...          122
# 62      sedan          fwd           front        98.8  ...          122
# 63      sedan          fwd           front        98.8  ...          122
# 64  hatchback          fwd           front        98.8  ...          122
# 66      sedan          rwd           front       104.9  ...          134
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 59         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 60         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 61         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 62         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 63          idi  3.39    3.39              22.7       64.0    4650.0       36
# 64         2bbl  3.39    3.39               8.6       84.0    4800.0       26
# 66          idi  3.43    3.64              22.0       72.0    4200.0       31
#
#     highway-mpg    price
# 59           32   8845.0
# 60           32   8495.0
# 61           32  10595.0
# 62           32  10245.0
# 63           42  10795.0
# 64           32  11245.0
# 66           39  18344.0
#
# [7 rows x 26 columns]

# %%
# getting most frequently value
nan_bore['bore'].mode()
# Out:
# 0    3.39
# Name: bore, dtype: float64

# %%
# from above observations replacing missing value with 3.39
data["bore"].replace(np.nan, 3.39, inplace=True)

# %% [markdown]
# ### Fill missing values in "stroke" column

# %%
# get all rows with null values in 'bore' column
data[data['stroke'].isnull()]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 57  hatchback          rwd           front        95.3  ...           70
# 58  hatchback          rwd           front        95.3  ...           80
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 57         4bbl  3.39     NaN               9.4      101.0    6000.0       17
# 58         mpfi  3.39     NaN               9.4      135.0    6000.0       16
#
#     highway-mpg    price
# 57           23  13645.0
# 58           23  15645.0
#
# [2 rows x 26 columns]

# %%
# check correlation with other numerical attributes
data[data.columns[1:]].corr()['stroke'][:-1]
# Out:
# normalized-losses    0.065627
# wheel-base           0.161477
# length               0.129739
# width                0.182956
# height              -0.056999
# curb-weight          0.168929
# engine-size          0.206675
# bore                -0.055909
# stroke               1.000000
# compression-ratio    0.186170
# horsepower           0.092337
# peak-rpm            -0.070322
# city-mpg            -0.042906
# highway-mpg         -0.044528
# Name: stroke, dtype: float64

# %% [markdown]
# Numerical columns are not correlated with "stroke", therefore we can't use for prediction NaN value in "stroke" attribute. Let's check what relation we can find with categorical attributes.

# %%
features = ["fuel-type","aspiration","drive-wheels","engine-location","engine-type","num-of-cylinders","fuel-system",]
plt.figure(figsize = (15,10))
for i in enumerate (features):
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(x = i[1],y = 'stroke',data = data)

# %%
sns.catplot(y="make", x="stroke", kind="box", data=data)

# %% [markdown]
# 1) By observing above plots and corrosponding values of other attributes, we can conclude that, missing values will be between 3.1 to 3.4.
#
# 2) We will impute missing value between given range by using mode. We are using mode because bore attribute is a categorical attribute.

# %%
# create dataframe by using above attributes and given range
nan_stroke = data[(data['stroke'] >= 3.1) & (data['stroke'] <= 3.4)& (data['make']=='mazda')]

# %%
# getting mode
nan_stroke['stroke'].mode()
# Out:
# 0    3.39
# Name: stroke, dtype: float64

# %%
# from above observations replacing missing value with 3.39
data["stroke"].replace(np.nan, 3.39, inplace=True)

# %% [markdown]
# We can also observe that bore attribute values and stroke attribute values are almost simillar, by considering this, above imputation is right.

# %% [markdown]
# ### Fill missing values in "Normalized losses" column

# %%
# get all rows with null values in 'bore' column
data[data['normalized-losses'].isnull()]
# Out:
#      symboling  normalized-losses           make fuel-type aspiration  \
# 0            3                NaN    alfa-romero       gas        std
# 1            3                NaN    alfa-romero       gas        std
# 2            1                NaN    alfa-romero       gas        std
# 5            2                NaN           audi       gas        std
# 7            1                NaN           audi       gas        std
# 9            0                NaN           audi       gas      turbo
# 14           1                NaN            bmw       gas        std
# 15           0                NaN            bmw       gas        std
# 16           0                NaN            bmw       gas        std
# 17           0                NaN            bmw       gas        std
# 43           0                NaN          isuzu       gas        std
# 44           1                NaN          isuzu       gas        std
# 45           0                NaN          isuzu       gas        std
# 46           2                NaN          isuzu       gas        std
# 48           0                NaN         jaguar       gas        std
# 49           0                NaN         jaguar       gas        std
# 63           0                NaN          mazda    diesel        std
# 66           0                NaN          mazda    diesel        std
# 71          -1                NaN  mercedes-benz       gas        std
# 73           0                NaN  mercedes-benz       gas        std
# 74           1                NaN  mercedes-benz       gas        std
# 75           1                NaN        mercury       gas      turbo
# 82           3                NaN     mitsubishi       gas      turbo
# 83           3                NaN     mitsubishi       gas      turbo
# 84           3                NaN     mitsubishi       gas      turbo
# 109          0                NaN         peugot       gas        std
# 110          0                NaN         peugot    diesel      turbo
# 113          0                NaN         peugot       gas        std
# 114          0                NaN         peugot    diesel      turbo
# 124          3                NaN       plymouth       gas      turbo
# 126          3                NaN        porsche       gas        std
# 127          3                NaN        porsche       gas        std
# 128          3                NaN        porsche       gas        std
# 129          1                NaN        porsche       gas        std
# 130          0                NaN        renault       gas        std
# 131          2                NaN        renault       gas        std
# 181         -1                NaN         toyota       gas        std
# 189          3                NaN     volkswagen       gas        std
# 191          0                NaN     volkswagen       gas        std
# 192          0                NaN     volkswagen    diesel      turbo
# 193          0                NaN     volkswagen       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 5            two        sedan          fwd           front        99.8  ...
# 7           four        wagon          fwd           front       105.8  ...
# 9            two    hatchback          4wd           front        99.5  ...
# 14          four        sedan          rwd           front       103.5  ...
# 15          four        sedan          rwd           front       103.5  ...
# 16           two        sedan          rwd           front       103.5  ...
# 17          four        sedan          rwd           front       110.0  ...
# 43          four        sedan          rwd           front        94.3  ...
# 44           two        sedan          fwd           front        94.5  ...
# 45          four        sedan          fwd           front        94.5  ...
# 46           two    hatchback          rwd           front        96.0  ...
# 48          four        sedan          rwd           front       113.0  ...
# 49           two        sedan          rwd           front       102.0  ...
# 63          four        sedan          fwd           front        98.8  ...
# 66          four        sedan          rwd           front       104.9  ...
# 71          four        sedan          rwd           front       115.6  ...
# 73          four        sedan          rwd           front       120.9  ...
# 74           two      hardtop          rwd           front       112.0  ...
# 75           two    hatchback          rwd           front       102.7  ...
# 82           two    hatchback          fwd           front        95.9  ...
# 83           two    hatchback          fwd           front        95.9  ...
# 84           two    hatchback          fwd           front        95.9  ...
# 109         four        wagon          rwd           front       114.2  ...
# 110         four        wagon          rwd           front       114.2  ...
# 113         four        wagon          rwd           front       114.2  ...
# 114         four        wagon          rwd           front       114.2  ...
# 124          two    hatchback          rwd           front        95.9  ...
# 126          two      hardtop          rwd            rear        89.5  ...
# 127          two      hardtop          rwd            rear        89.5  ...
# 128          two  convertible          rwd            rear        89.5  ...
# 129          two    hatchback          rwd           front        98.4  ...
# 130         four        wagon          fwd           front        96.1  ...
# 131          two    hatchback          fwd           front        96.1  ...
# 181         four        wagon          rwd           front       104.5  ...
# 189          two  convertible          fwd           front        94.5  ...
# 191         four        sedan          fwd           front       100.4  ...
# 192         four        sedan          fwd           front       100.4  ...
# 193         four        wagon          fwd           front       100.4  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0      111.0
# 1            130         mpfi  3.47    2.68               9.0      111.0
# 2            152         mpfi  2.68    3.47               9.0      154.0
# 5            136         mpfi  3.19    3.40               8.5      110.0
# 7            136         mpfi  3.19    3.40               8.5      110.0
# 9            131         mpfi  3.13    3.40               7.0      160.0
# 14           164         mpfi  3.31    3.19               9.0      121.0
# 15           209         mpfi  3.62    3.39               8.0      182.0
# 16           209         mpfi  3.62    3.39               8.0      182.0
# 17           209         mpfi  3.62    3.39               8.0      182.0
# 43           111         2bbl  3.31    3.23               8.5       78.0
# 44            90         2bbl  3.03    3.11               9.6       70.0
# 45            90         2bbl  3.03    3.11               9.6       70.0
# 46           119         spfi  3.43    3.23               9.2       90.0
# 48           258         mpfi  3.63    4.17               8.1      176.0
# 49           326         mpfi  3.54    2.76              11.5      262.0
# 63           122          idi  3.39    3.39              22.7       64.0
# 66           134          idi  3.43    3.64              22.0       72.0
# 71           234         mpfi  3.46    3.10               8.3      155.0
# 73           308         mpfi  3.80    3.35               8.0      184.0
# 74           304         mpfi  3.80    3.35               8.0      184.0
# 75           140         mpfi  3.78    3.12               8.0      175.0
# 82           156         spdi  3.58    3.86               7.0      145.0
# 83           156         spdi  3.59    3.86               7.0      145.0
# 84           156         spdi  3.59    3.86               7.0      145.0
# 109          120         mpfi  3.46    3.19               8.4       97.0
# 110          152          idi  3.70    3.52              21.0       95.0
# 113          120         mpfi  3.46    2.19               8.4       95.0
# 114          152          idi  3.70    3.52              21.0       95.0
# 124          156         spdi  3.59    3.86               7.0      145.0
# 126          194         mpfi  3.74    2.90               9.5      207.0
# 127          194         mpfi  3.74    2.90               9.5      207.0
# 128          194         mpfi  3.74    2.90               9.5      207.0
# 129          203         mpfi  3.94    3.11              10.0      288.0
# 130          132         mpfi  3.46    3.90               8.7      112.0
# 131          132         mpfi  3.46    3.90               8.7      112.0
# 181          161         mpfi  3.27    3.35               9.2      156.0
# 189          109         mpfi  3.19    3.40               8.5       90.0
# 191          136         mpfi  3.19    3.40               8.5      110.0
# 192           97          idi  3.01    3.40              23.0       68.0
# 193          109         mpfi  3.19    3.40               9.0       88.0
#
#      peak-rpm city-mpg  highway-mpg    price
# 0      5000.0       21           27  13495.0
# 1      5000.0       21           27  16500.0
# 2      5000.0       19           26  16500.0
# 5      5500.0       19           25  15250.0
# 7      5500.0       19           25  18920.0
# 9      5500.0       16           22      NaN
# 14     4250.0       20           25  24565.0
# 15     5400.0       16           22  30760.0
# 16     5400.0       16           22  41315.0
# 17     5400.0       15           20  36880.0
# 43     4800.0       24           29   6785.0
# 44     5400.0       38           43      NaN
# 45     5400.0       38           43      NaN
# 46     5000.0       24           29  11048.0
# 48     4750.0       15           19  35550.0
# 49     5000.0       13           17  36000.0
# 63     4650.0       36           42  10795.0
# 66     4200.0       31           39  18344.0
# 71     4750.0       16           18  34184.0
# 73     4500.0       14           16  40960.0
# 74     4500.0       14           16  45400.0
# 75     5000.0       19           24  16503.0
# 82     5000.0       19           24  12629.0
# 83     5000.0       19           24  14869.0
# 84     5000.0       19           24  14489.0
# 109    5000.0       19           24  12440.0
# 110    4150.0       25           25  13860.0
# 113    5000.0       19           24  16695.0
# 114    4150.0       25           25  17075.0
# 124    5000.0       19           24  12764.0
# 126    5900.0       17           25  32528.0
# 127    5900.0       17           25  34028.0
# 128    5900.0       17           25  37028.0
# 129    5750.0       17           28      NaN
# 130    5100.0       23           31   9295.0
# 131    5100.0       23           31   9895.0
# 181    5200.0       19           24  15750.0
# 189    5500.0       24           29  11595.0
# 191    5500.0       19           24  13295.0
# 192    4500.0       33           38  13845.0
# 193    5500.0       25           31  12290.0
#
# [41 rows x 26 columns]

# %%
# check correlation with other numerical attributes
data[data.columns[1:]].corr()['normalized-losses'][:-1]
# Out:
# normalized-losses    1.000000
# wheel-base          -0.069276
# length               0.026117
# width                0.104965
# height              -0.424930
# curb-weight          0.122004
# engine-size          0.186115
# bore                -0.032582
# stroke               0.070423
# compression-ratio   -0.131334
# horsepower           0.295418
# peak-rpm             0.253048
# city-mpg            -0.248245
# highway-mpg         -0.200520
# Name: normalized-losses, dtype: float64

# %% [markdown]
# 1) Numerical columns are not correlated with "normalized-losses", therefore we can't use for imputing missing values in "normalized-losses" attribute.
#
# 2) Also we can't use catergorical columns because we have different categories in other attributes for all missing values in normalized categories. This condition occured because we have more number of missing values as compare to all data points.
#
# 3) We will use either mean, mode, or medain by using distribution.

# %% [markdown]
# #### Let's check distribution

# %%
# plotiing kde plot to check distribution
sns.set_style('whitegrid')
sns.kdeplot(data['normalized-losses'], bw=0.5)
# Out:
# <AxesSubplot:xlabel='normalized-losses', ylabel='Density'>

# %% [markdown]
# Above distribution looks like normal distribution. So for imputing missing values we can use either mean or median.

# %%
# getting median value
median = data['normalized-losses'].median()

# %%
# from above observations replacing missing value with median
data["normalized-losses"].replace(np.nan, median, inplace=True)

# %% [markdown]
# ### Handle missing values in "price " column
# we have price column with missing values. so we will take out these rows currently. We can use these rows for test data.

# %%
data_without_price = data[data['price'].isnull()]

# %%
# drop whole row with NaN in "price" column
data.dropna(subset=["price"], axis=0, inplace=True)

# reset index, because we droped rows
data.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### We have handled all the missing values.

# %% [markdown]
# ### Check there any missing value remain

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### No missing value

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Analysis of numerical attributes

# %% [markdown]
# From below describe function we will get following observations, it is also calles as descriptive statistical analysis
#
# 1) the count of that variable
#
# 2) the mean
#
# 3) the standard deviation (std)
#
# 4) the minimum value
#
# 5) the IQR (Interquartile Range: 25%, 50% and 75%)
#
# 6) the maximum value

# %%
# describe numerical attributes
data.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  199.000000         199.000000  199.000000  199.000000  199.000000
# mean     0.819095         120.417085   98.832161  174.253266   65.890955
# std      1.242122          32.137519    6.086686   12.373104    2.111971
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          99.500000   94.500000  166.550000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         137.000000  102.400000  183.500000   66.750000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  199.000000   199.000000   199.000000  199.000000  199.000000
# mean    53.808543  2557.432161   127.447236    3.331307    3.258241
# std      2.423887   519.599899    41.359058    0.269488    0.317918
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2157.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2420.000000   120.000000    3.310000    3.290000
# 75%     55.550000  2930.500000   143.000000    3.585000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         199.000000  199.000000   199.000000  199.000000   199.000000
# mean           10.171960  103.507538  5108.542714   25.261307    30.763819
# std             4.024401   37.562859   472.183181    6.402498     6.805338
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.550000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5100.000000   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price
# count    199.000000
# mean   13225.341709
# std     7984.876506
# min     5118.000000
# 25%     7775.000000
# 50%    10245.000000
# 75%    16501.500000
# max    45400.000000

# %%
# taking numerical features for plotting scatter plot
num_features = ['symboling','normalized-losses','wheel-base','length','width','height','curb-weight','engine-size','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg']

# %%
# scatter plot for all numerical attributes
plt.figure(figsize = (15,25))
for i in enumerate (num_features):
    plt.subplot(5,3,i[0]+1)
    sns.scatterplot(x = i[1],y = 'price',data = data)

# %%
# correlation of numerical attributes
sns.set(rc = {'figure.figsize':(12,8)})
dataplot = sns.heatmap(data.corr(),cmap="YlGnBu",annot=True)

# %% [markdown]
# ### Observations from scatter plots and correlation matrix:
# 1) There is a positive linear relationship between price and following attributes(wheel base, length, width, curb weight, engine size, bore, horsepower). From this we can say that, when overall size and engine of vehicle increase, it's price also increase.
#
# 2) There is a inverse relationship between price and following attributes( city mpg, highway mpg). As we can see in correlation matrix almost all attributes has negative relationship with these attributes. So we can say that, when overall size of vehicle increases it,s mpg decreases.
#
# 3) Compression ratio and height attributes has very less relation with other attributes.
#
# 4) Other attributes has no relation between "price".
#
# All above observations are only for numerical attributes. For categorical attributes we will use box plot.

# %% [markdown]
# ### Analysis of categorical attributes

# %%
# taking categorical features for plotting box plot
cat_features = ['fuel-type', 'aspiration',
       'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
        'engine-type','num-of-cylinders', 'fuel-system']

# %%
# box plot for all ctegorical features
plt.figure(figsize = (15,18))
for i in enumerate (cat_features):
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(x = i[1],y = 'price',data = data)
sns.catplot(y="make", x="price", kind="box", data=data)

# %% [markdown]
# ### Observations on categorical attributes:
# 1) In engine location vs price box plot we can see huge price difference between front and rear engine location. This is not only because of engine location, price is affected because of make. All these rear engine location models only made by porsche and may be porsche make vehicals are costlier.
#
# 2) From above plots we observe that rear wheel drive, rear engine location, eight number of cylinders, mercedes-benz, jaguar and porsche make vehicles are costier than others.
#
# 3) We observe that data has some outliears but we are not removing it because we have very small data.

# %% [markdown]
# # Make data model ready

# %% [markdown]
# ### Encode categorical features
# converting all categorical features into numerical fetures by using dummy encoder function

# %%
# list of all categorical attributes
cat_features = ['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','engine-type','num-of-cylinders','fuel-system']

# %%
encoded_data = pd.get_dummies(data, columns = cat_features)

# %%
encoded_data.shape
# Out:
# (199, 75)

# %% [markdown]
# Data points = 199
#
# Features = 75

# %% [markdown]
# ### split data into independant and target data

# %%
X = encoded_data.drop('price', axis = 1)
y = encoded_data['price']

# %%
print(X.shape,y.shape)
# Out:
# (199, 74) (199,)

# %% [markdown]
# ### split data into train and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 15)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (133, 74) (66, 74) (133,) (66,)

# %% [markdown]
# We are using 67% data points for training and 33% data points for test.

# %% [markdown]
# ### Data Standardization
# Standardization data means bringing all attributes on same scale with mean = 0 and standard deviation = 1.

# %%
scaler = StandardScaler()
std_X_train = scaler.fit_transform(X_train)
std_X_test = scaler.transform(X_test)

# %% [markdown]
# # Model deployment

# %% [markdown]
# We will start from simple models.

# %%
# import required liabraries for model deploy
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Apply Linear Regression
#
# Linear Regression model require linearly seperable data

# %%
lr = LinearRegression()
lr.fit(std_X_train, y_train)
print('train accuracy : ',lr.score(std_X_train, y_train))
print('test accuracy : ',lr.score(std_X_test, y_test))
# Out:
# train accuracy :  0.9740025546592501
# test accuracy :  -2.0052192299924608e+23

# %% [markdown]
# accuracy = 1 == Best model
#
# accuracy = 0 == simple mean model
#
# accurcy between 0 and 1 == model is better than simple mean model
#
# accuracy = < 0 or in -ve == model is performing worse
#
# simple mean model = model is predicting mean value of target y, prediction for all x, model will return mean of y.

# %% [markdown]
# ### Mean Squared Error
#
# The Mean Squared Error measures the average of the squares of errors, that is, the difference between actual value (y) and the estimated value (ŷ).
#
# ŷ = predicted value.

# %%
y_pred = lr.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  5.576257056549355e+30

# %% [markdown]
# ### Plot Residual Error
# Residual Error = The difference between the observed value (y) and the predicted value (ŷ) is called the residual (e). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.

# %%
# regression coefficients
print('Coefficients: ', lr.coef_)
  
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(lr.score(std_X_test, y_test)))
  
# plot for residual error
  
## setting plot style
plt.style.use('fivethirtyeight')

plt.figure(figsize = (8,5))
  
## plotting residual errors in training data
plt.scatter(lr.predict(std_X_train), lr.predict(std_X_train) - y_train,
            color = "green", s = 10, label = 'Train data')
  
## plotting residual errors in test data
plt.scatter(lr.predict(std_X_test), lr.predict(std_X_test) - y_test,
            color = "blue", s = 10, label = 'Test data')
  
## plotting line for zero residual error
plt.hlines(y = 0, xmin = -60000000000000000, xmax = 20000000000000000, linewidth = 2)
  
## plotting legend
plt.legend(loc = 'upper right')
  
## plot title
plt.title("Residual errors")
  
## method call for showing the plot
plt.show()
# Out:
# Coefficients:  [-1.08233298e+03 -3.00700858e+02  1.94926492e+03 -2.49651816e+03
#   1.18923558e+03 -1.34553167e+03  4.88728906e+03  4.98730980e+03
#  -9.87677193e+02 -1.67183015e+02 -3.70855291e+03 -1.38288659e+03
#   1.08392886e+03 -1.21831086e+03  2.19590869e+03  8.86282074e+14
#   1.38519625e+15  1.38519625e+15  1.08131847e+15  1.38519625e+15
#   1.82916725e+15  8.86282074e+14  1.08131847e+15  1.92032120e+15
#   1.62613131e+15  6.29083487e+14  1.82916725e+15  2.08643389e+15
#  -6.74539439e+14  1.08131847e+15 -1.76723268e+15  8.86282074e+14
#   1.38519625e+15 -1.20639893e+15  2.43150281e+15  1.73149531e+15
#   1.51146747e+15 -1.33948412e+15 -7.54412610e+14 -1.23029985e+14
#  -1.23029985e+14  7.19055493e+14  7.19055493e+14 -1.21515634e+15
#  -1.21515634e+15 -3.00582376e+15 -3.18689086e+15 -2.13302343e+15
#  -2.79412854e+14 -8.12762011e+14 -8.05656984e+14 -1.54195190e+15
#  -5.76930844e+14  7.04901746e+14  3.33337709e+15  1.24257145e+15
#   4.04987630e+15  7.04901746e+14  3.67095728e+14  5.73859621e+14
#   7.98878652e+14  1.43620519e+15  1.09303417e+15 -5.70822693e+14
#   2.90247028e+14  3.67149704e+14 -7.84034551e+14 -1.48966565e+15
#  -2.84853898e+14 -3.94187332e+14 -2.84853898e+14 -1.64759223e+15
#  -7.36324912e+14 -2.84853898e+14]
# Variance score: -2.0052192299924608e+23

# %% [markdown]
# Here we have got very good train accuracy = 0.97 and very bad test accuracy = -2.005. This means our model is overfitted.
#
# Overfitting = It means that the model performs well on the training data, but it does not generalize well, means it not performs well on test data.
#
# #### Model's performance is bad so, we are not using it.

# %% [markdown]
# ## Apply Ridge Regression

# %% [markdown]
# Ridge Regressing is a modified version of Linear Regression. In ridge regression we use regularization technique.
#
# Regularization refers to techniques that are used to calibrate machine learning models in order to minimize the adjusted loss function and prevent overfitting or underfitting

# %%
reg = Ridge()
reg.fit(std_X_train, y_train)
print('train accuracy : ',reg.score(std_X_train, y_train))
print('test accuracy : ',reg.score(std_X_test, y_test))
# Out:
# train accuracy :  0.9723719968553693
# test accuracy :  0.8830943344632624

# %% [markdown]
# ### Mean Squared Error

# %%
y_pred = reg.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  3250996.3631372256

# %% [markdown]
# ### Top 10 important features
#
# These are the features are most usefull for prediction>

# %%
features = X.columns
# get importance
importance = abs(reg.coef_)
# summarize feature importance
imp_features = {}
for i in range(len(features)):
    imp_features[features[i]] = importance[i]
top_10 = (sorted(imp_features.items(), key=lambda x: x[1], reverse=True)[:10])
top_10
# Out:
# [('engine-size', 3166.6008787716078),
#  ('curb-weight', 2534.6110927396517),
#  ('make_bmw', 1680.2822823078575),
#  ('wheel-base', 1521.340400782578),
#  ('length', 1422.8106982272068),
#  ('width', 1283.9986391289438),
#  ('num-of-cylinders_eight', 1022.4596846749619),
#  ('highway-mpg', 986.5512818276721),
#  ('height', 983.4098981200411),
#  ('make_audi', 980.486694042635)]

# %% [markdown]
# ### Plot Residual Error

# %%
# regression coefficients
print('Coefficients: ', reg.coef_)
  
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(reg.score(std_X_test, y_test)))
  
# plot for residual error
plt.figure(figsize = (8,5))  
## setting plot style
plt.style.use('fivethirtyeight')
  
## plotting residual errors in training data
plt.scatter(reg.predict(std_X_train), reg.predict(std_X_train) - y_train,
            color = "green", s = 10, label = 'Train data')
  
## plotting residual errors in test data
plt.scatter(reg.predict(std_X_test), reg.predict(std_X_test) - y_test,
            color = "blue", s = 10, label = 'Test data')
  
## plotting line for zero residual error
plt.hlines(y = 0, xmin = 0, xmax = 40000, linewidth = 2)
  
## plotting legend
plt.legend(loc = 'upper right')
  
## plot title
plt.title("Residual errors")
  
## method call for showing the plot
plt.show()
# Out:
# Coefficients:  [-8.60536365e+02 -3.25779208e+02  1.52134040e+03 -1.42281070e+03
#   1.28399864e+03 -9.83409898e+02  2.53461109e+03  3.16660088e+03
#  -2.35276965e+02 -4.66762771e+02 -8.30006425e+02  6.01517577e+02
#   7.59043774e+02 -4.19500409e+02  9.86551282e+02  2.94179685e+01
#   9.80486694e+02  1.68028228e+03 -4.46444823e+02 -4.96411071e+02
#  -6.46962578e+02 -2.91741627e+02  3.94011183e+02  1.47514970e+02
#   6.99024295e+02 -2.54843735e+02 -7.06838418e+02 -1.74155034e+02
#  -3.59228071e+02 -5.23351582e+02  6.24412082e+02 -1.34228898e+02
#   9.75705723e+02 -3.95174652e+02 -5.38950939e+02  3.68612320e+02
#  -3.30007605e+02  2.07475785e+02 -2.07475785e+02 -4.46242444e+02
#   4.46242444e+02 -2.29969684e+02  2.29969684e+02  6.22876407e+02
#   2.17899485e+02 -3.82542085e+02  2.01551824e+01  2.99797755e+01
#   2.42694060e+02 -3.89545048e+02  3.08810799e+02 -6.24412082e+02
#   6.24412082e+02 -9.77824437e-01 -1.66397620e+02  3.59026433e+02
#   1.69671849e+01 -6.18522153e+02  2.94789377e+02  1.02245968e+03
#  -5.98427370e+02 -3.18313531e+02  1.58087743e+02  5.36576389e+02
#  -3.46574767e+02  2.94789377e+02  2.84280178e+02  2.91961084e+02
#  -8.20628755e+01  2.07475785e+02 -7.92780635e+01 -4.00192407e+02
#  -2.28923106e+02  4.52579543e+01]
# Variance score: 0.8830943344632624

# %% [markdown]
# We got train accuracy = 0.97 and train accuracy = 0.88. See accuracy is improved.
#
# To increase accuracy and generalize model well, we use cross-validation and hyperparameter tunning technique. But here we have very less data, so we are not doing it here. If we do cross-validation our model will not be able to understand underlying structure or pattern of data. If we have large dataset then surely we will gone for the cross-validation and hyperparameter tunning.
#
# Let's try another model.

# %% [markdown]
# # Apply Lasso Regression

# %% [markdown]
# Ridge and Lasso regressions are almost similar only difference is Ridge regression uses L2 regularization and Lasso regression uses L1 regularization.
#
# The differences between L1 and L2 regularization:
# L1 regularization penalizes the sum of absolute values of the weights, whereas L2 regularization penalizes the sum of squares of the weights

# %%
lasso = Lasso()
lasso.fit(std_X_train, y_train)
print('train accuracy : ',lasso.score(std_X_train, y_train))
print('test accuracy : ',lasso.score(std_X_test, y_test))
# Out:
# train accuracy :  0.9741378641878524
# test accuracy :  0.8220530849480443

# %% [markdown]
# ### Mean squared error

# %%
y_pred = lasso.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  4948475.088947694

# %% [markdown]
# ### Plot Residual Error

# %%
# regression coefficients
print('Coefficients: ', lasso.coef_)
  
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(lasso.score(std_X_test, y_test)))
  
# plot for residual error
plt.figure(figsize = (8,5))    
## setting plot style
plt.style.use('fivethirtyeight')
  
## plotting residual errors in training data
plt.scatter(lasso.predict(std_X_train), lasso.predict(std_X_train) - y_train,
            color = "green", s = 10, label = 'Train data')
  
## plotting residual errors in test data
plt.scatter(lasso.predict(std_X_test), lasso.predict(std_X_test) - y_test,
            color = "blue", s = 10, label = 'Test data')
  
## plotting line for zero residual error
plt.hlines(y = 0, xmin = 0, xmax = 40000, linewidth = 2)
  
## plotting legend
plt.legend(loc = 'upper right')
  
## plot title
plt.title("Residual errors")
  
## method call for showing the plot
plt.show()
# Out:
# Coefficients:  [-1.05496596e+03 -3.26137470e+02  1.97226763e+03 -2.42196826e+03
#   1.15174559e+03 -1.32850645e+03  4.53962011e+03  4.66549361e+03
#  -8.50860333e+02 -1.93534210e+02 -3.04281338e+03 -1.01053728e+03
#   1.08044701e+03 -9.87005990e+02  1.93108634e+03  1.31964020e+02
#   1.42110565e+03  2.03725275e+03 -3.78967505e+02 -5.54495732e+02
#  -6.10927225e+02 -2.50591151e+02 -2.32930083e+02  3.95077676e+02
#   8.81826921e+02  1.65526385e-01 -7.14057284e+02  1.79740533e+02
#  -2.89805358e+02 -5.60758283e+02  2.42340586e+03  3.47965310e+00
#   1.50029329e+03  0.00000000e+00 -2.06990930e+02  7.93686555e+02
#  -4.53634130e+01  2.30254214e+03 -0.00000000e+00 -1.10948394e+03
#   7.60761546e-14 -4.70804970e+02  4.97179040e-11  5.55359158e+02
#   2.61414729e+02 -5.17384833e+02 -0.00000000e+00  6.45494577e+01
#   6.43744910e+01 -7.52643220e+02  0.00000000e+00 -8.10579253e+01
#   0.00000000e+00  1.29978349e+02 -4.11360488e+02 -0.00000000e+00
#   0.00000000e+00 -6.12746306e+02  8.95168308e+02  4.15177463e+02
#  -8.66485912e+02  0.00000000e+00 -1.92985860e+02  6.54383514e+02
#  -6.65190011e+01  0.00000000e+00  3.26654127e+02  5.28051072e+02
#  -1.17073545e+02  0.00000000e+00 -6.48226191e+01 -3.34118930e+02
#  -2.21910903e+02  7.01807603e+01]
# Variance score: 0.8220530849480443

# %% [markdown]
# For Lasso model we got train accuracy = 0.97 and test accuracy = 0.82 which is less than Ridge regression.
#
# Here we are not getting accuracy more than 90% for linear regression models. May be this is because data is not linearly separable.
#
# Let's try polynomial SVR

# %% [markdown]
# ## Apply Support Vector Regressor

# %% [markdown]
# Polynomial Kernel: It represents the similarity of vectors in the training set of data in a feature space over polynomials of the original variables used in the kernel.

# %%
poly = SVR(kernel = 'poly', degree = 3 ,C=1.0)
poly.fit(std_X_train, y_train)
print('train accuracy : ',poly.score(std_X_train, y_train))
print('test accuracy : ',poly.score(std_X_test, y_test))
# Out:
# train accuracy :  -0.1293176566264247
# test accuracy :  0.0004945800803959344

# %% [markdown]
# ### Mean squared error

# %%
y_pred = poly.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  27794961.605803937

# %% [markdown]
# ### Plot Residual Error

# %%
# variance score: 1 means perfect prediction
print('Variance score: {}'.format(poly.score(std_X_test, y_test)))
  
# plot for residual error
plt.figure(figsize = (8,5))    
## setting plot style
plt.style.use('fivethirtyeight')
  
## plotting residual errors in training data
plt.scatter(poly.predict(std_X_train), poly.predict(std_X_train) - y_train,
            color = "green", s = 10, label = 'Train data')
  
## plotting residual errors in test data
plt.scatter(poly.predict(std_X_test), poly.predict(std_X_test) - y_test,
            color = "blue", s = 10, label = 'Test data')
  
## plotting line for zero residual error
plt.hlines(y = 0, xmin = 0, xmax = 15000, linewidth = 2)
  
## plotting legend
plt.legend(loc = 'upper right')
  
## plot title
plt.title("Residual errors")
  
## method call for showing the plot
plt.show()
# Out:
# Variance score: 0.0004945800803959344

# %% [markdown]
# For SVR model we got train accuracy = -0.126 and test accuracy = 0.00049 which is less than Ridge and Lasso regression.

# %% [markdown]
# # Compare all models

# %%
# http://zetcode.com/python/prettytable/
from prettytable import PrettyTable
from prettytable import ALL as ALL
table=PrettyTable(hrules=ALL)
table.field_names = ["Sr.No.", "Model", "Train accuracy", "Test accuracy", "MSE"] 
table.add_row([1, "Linear Regression", 0.974 , -2.005e+23, 5.57e+30 ])
table.add_row([2, "Ridge Regression", 0.972 , 0.883, 3250996.36 ])
table.add_row([3, "Lasso Regression", 0.974 , 0.822, 4948475.08 ])
table.add_row([4, "Polynomial SVR", -0.12 , 0.00049, 27794961.60 ])

print(table)
# Out:
# +--------+-------------------+----------------+---------------+------------+
# | Sr.No. |       Model       | Train accuracy | Test accuracy |    MSE     |
# +--------+-------------------+----------------+---------------+------------+
# |   1    | Linear Regression |     0.974      |   -2.005e+23  |  5.57e+30  |
# +--------+-------------------+----------------+---------------+------------+
# |   2    |  Ridge Regression |     0.972      |     0.883     | 3250996.36 |
# +--------+-------------------+----------------+---------------+------------+
# |   3    |  Lasso Regression |     0.974      |     0.822     | 4948475.08 |
# +--------+-------------------+----------------+---------------+------------+
# |   4    |   Polynomial SVR  |     -0.12      |    0.00049    | 27794961.6 |
# +--------+-------------------+----------------+---------------+------------+

# %% [markdown]
# Comparing above models Ridge Regression got high accuracy.

# %% [markdown]
# ## Deploy new model by dropping less important features

# %% [markdown]
# Now, we have got best model for price prediction. But here we have considered all attributes. For models like linear regression we should not consider attributes which are correlated to each other, numerical attributes which are  non linearly related to our target attribute and categorical attributes which are not seperable with target variable.
#
# Let's check which are these attributes.
#
# We can find out these attributes by using scatter plot, box plot and correlation matrix, whcih are we have already discussed in EDA section.

# %% [markdown]
# ### Non linear relation

# %%
plt.figure(figsize = (6,5))
sns.scatterplot(x = 'symboling',y = 'price',data = data)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %% [markdown]
# ### Positive linear relation

# %%
plt.figure(figsize = (6,5))
sns.scatterplot(x = 'engine-size',y = 'price',data = data)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %% [markdown]
# ### Negative linear relation

# %%
plt.figure(figsize = (6,5))
sns.scatterplot(x = 'highway-mpg',y = 'price',data = data)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# ### Non seperable relation

# %%
sns.catplot(x="num-of-doors", y="price", kind="box", data=data)

# %% [markdown]
# Here we can see that price of 2 doors and 4 doors are overlaping. Means we can not predict price of vehicle by using this feature.

# %% [markdown]
# ### Seperable Relation

# %%
sns.catplot(x="engine-location", y="price", kind="box", data=data)

# %% [markdown]
# Here we can clearly see that price of front engine location is between 7500 to 16000 and price of rear engine lication vehicle is between 33000 to 36000, we can seperate these two categories easily. This kind of attributes are very usefull for prediction.

# %%
# correlation of numerical attributes
sns.set(rc = {'figure.figsize':(12,8)})
dataplot = sns.heatmap(data.corr(),cmap="YlGnBu",annot=True)

# %% [markdown]
# Right side we can see scale from 0 to 1. 0 means not coreelated 1 means highly positive correlated and -ve means negative correlated.
#
# Wheel base and length features shows 0.88 correlated means these two are highly correlated. We can drop one of these columns.
#
# Now, by using scatter plot, box plot and correlation matrix we will drop less important features and build model and check it's accuracy. If accuracy is approximate equal we will select model which has less features.

# %% [markdown]
# ## Drop features / columns

# %%
# create list of less important features
drop_columns = ['symboling', 'normalized-losses','height','stroke','compression-ratio','peak-rpm','city-mpg','curb-weight','length','num-of-doors']

# %%
# drop less important features
new_data = data.drop(drop_columns, axis = 1)

# %%
new_data.head(2)
# Out:
#           make fuel-type aspiration   body-style drive-wheels engine-location  \
# 0  alfa-romero       gas        std  convertible          rwd           front
# 1  alfa-romero       gas        std  convertible          rwd           front
#
#    wheel-base  width engine-type num-of-cylinders  engine-size fuel-system  \
# 0        88.6   64.1        dohc             four          130        mpfi
# 1        88.6   64.1        dohc             four          130        mpfi
#
#    bore  horsepower  highway-mpg    price
# 0  3.47       111.0           27  13495.0
# 1  3.47       111.0           27  16500.0

# %%
# list of all categorical attributes
new_cat_features = ['make','fuel-type','aspiration','body-style','drive-wheels','engine-location','engine-type','num-of-cylinders','fuel-system']

# %%
# one hot encoding
new_encoded_data = pd.get_dummies(new_data, columns = new_cat_features)

# %%
# number of rows and columns after encoding
new_encoded_data.shape
# Out:
# (199, 64)

# %%
X = new_encoded_data.drop('price', axis = 1)
y = new_encoded_data['price']

# %%
# split into train and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = 15)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (133, 63) (66, 63) (133,) (66,)

# %% [markdown]
# ## Data Standardization

# %%
scaler = StandardScaler()
std_X_train = scaler.fit_transform(X_train)
std_X_test = scaler.transform(X_test)

# %% [markdown]
# ## Apply Linear Regression

# %%
lr = LinearRegression()
lr.fit(std_X_train, y_train)
print('train accuracy : ',lr.score(std_X_train, y_train))
print('test accuracy : ',lr.score(std_X_test, y_test))
# Out:
# train accuracy :  0.9641697126406666
# test accuracy :  0.8716189902578486

# %% [markdown]
# ## Mean Squared Error

# %%
y_pred = lr.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  3570110.9424543804

# %% [markdown]
# ### Top 10 important features

# %%
features = X.columns
# get importance
importance = abs(lr.coef_)
# summarize feature importance
imp_features = {}
for i in range(len(features)):
    imp_features[features[i]] = importance[i]
top_10 = (sorted(imp_features.items(), key=lambda x: x[1], reverse=True)[:10])
top_10
# Out:
# [('engine-size', 2968.2957248850885),
#  ('horsepower', 2033.441347230194),
#  ('make_bmw', 1836.2421678532696),
#  ('width', 1312.607698934901),
#  ('wheel-base', 1070.1142766242094),
#  ('num-of-cylinders_eight', 876.8430509169507),
#  ('make_jaguar', 819.090722696777),
#  ('make_mercedes-benz', 805.0384356086629),
#  ('body-style_convertible', 767.2364650452532),
#  ('bore', 710.7110949082996)]

# %% [markdown]
# ## Apply Ridge Regression

# %%
reg = Ridge()
reg.fit(std_X_train, y_train)
print('train accuracy : ',reg.score(std_X_train, y_train))
print('test accuracy : ',reg.score(std_X_test, y_test))
# Out:
# train accuracy :  0.9640151264783446
# test accuracy :  0.8709536292254494

# %% [markdown]
# ## Mean Squared Error

# %%
y_pred = reg.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  3588613.777937776

# %% [markdown]
# ### Top 10 important features

# %%
features = X.columns
# get importance
importance = abs(reg.coef_)
# summarize feature importance
imp_features = {}
for i in range(len(features)):
    imp_features[features[i]] = importance[i]
top_10 = (sorted(imp_features.items(), key=lambda x: x[1], reverse=True)[:10])
top_10
# Out:
# [('engine-size', 2428.355167960665),
#  ('horsepower', 1884.208692761036),
#  ('make_bmw', 1760.2773994387073),
#  ('width', 1316.0076827180062),
#  ('num-of-cylinders_eight', 1103.667819911629),
#  ('wheel-base', 1058.490669398812),
#  ('make_jaguar', 885.4569874559785),
#  ('make_mercedes-benz', 796.5997043959388),
#  ('body-style_convertible', 747.1014192690704),
#  ('make_porsche', 609.5073398370353)]

# %% [markdown]
# ## Apply Lasso Regression

# %%
lasso = Lasso()
lasso.fit(std_X_train, y_train)
print('train accuracy : ',lasso.score(std_X_train, y_train))
print('test accuracy : ',lasso.score(std_X_test, y_test))
# Out:
# train accuracy :  0.9641664385148627
# test accuracy :  0.8545053475033556

# %% [markdown]
# ## Mean Squared Error

# %%
y_pred = lasso.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  4046019.3605746534

# %% [markdown]
# ## Apply support vector regressor

# %%
poly = SVR(kernel = 'poly', degree = 3 ,C=1.0)
poly.fit(std_X_train, y_train)
print('train accuracy : ',poly.score(std_X_train, y_train))
print('test accuracy : ',poly.score(std_X_test, y_test))
# Out:
# train accuracy :  -0.12893201756023198
# test accuracy :  0.00029524018321958057

# %% [markdown]
# ## Mean Squared Error

# %%
y_pred = poly.predict(std_X_test)
print('MSE = ',mean_squared_error(y_pred, y_test))
# Out:
# MSE =  27800504.992240965

# %% [markdown]
# ## Compare model after removing less important features

# %%
# http://zetcode.com/python/prettytable/
from prettytable import PrettyTable
from prettytable import ALL as ALL
table=PrettyTable(hrules=ALL)
table.field_names = ["Sr.No.", "Model", "Train accuracy", "Test accuracy", "MSE"] 
table.add_row([1, "Linear Regression", 0.964 , 0.871, 3570110.94 ])
table.add_row([2, "Ridge Regression", 0.964 , 0.870, 3588613.77 ])
table.add_row([3, "Lasso Regression", 0.964 , 0.854, 4046019.36 ])
table.add_row([4, "Polynomial SVR", -0.128 , 0.00029, 27800504.99 ])

print(table)
# Out:
# +--------+-------------------+----------------+---------------+-------------+
# | Sr.No. |       Model       | Train accuracy | Test accuracy |     MSE     |
# +--------+-------------------+----------------+---------------+-------------+
# |   1    | Linear Regression |     0.964      |     0.871     |  3570110.94 |
# +--------+-------------------+----------------+---------------+-------------+
# |   2    |  Ridge Regression |     0.964      |      0.87     |  3588613.77 |
# +--------+-------------------+----------------+---------------+-------------+
# |   3    |  Lasso Regression |     0.964      |     0.854     |  4046019.36 |
# +--------+-------------------+----------------+---------------+-------------+
# |   4    |   Polynomial SVR  |     -0.128     |    0.00029    | 27800504.99 |
# +--------+-------------------+----------------+---------------+-------------+

# %% [markdown]
# Comparing above models Linear and Ridge Regression got almost equal accuracy, we can use either of them.

# %% [markdown]
# ## Let's compare accuracy of models with all features and accuracy of models after removing less important features

# %%
table1=PrettyTable(hrules=ALL)
table1.field_names = ["Sr.No.", "Model", "Train accuracy", "Test accuracy", "MSE"] 
table1.add_row([1, "Linear Regression", 0.974 , -2.005e+23, 5.57e+30 ])
table1.add_row([2, "Ridge Regression", 0.972 , 0.883, 3250996.36 ])
table1.add_row([3, "Lasso Regression", 0.974 , 0.822, 4948475.08 ])
table1.add_row([4, "Polynomial SVR", -0.12 , 0.00049, 27794961.60 ])
print('Accuracy of models with all features')
print(table1)
table2=PrettyTable(hrules=ALL)
table2.field_names = ["Sr.No.", "Model", "Train accuracy", "Test accuracy", "MSE"] 
table2.add_row([1, "Linear Regression", 0.964 , 0.871, 3570110.94 ])
table2.add_row([2, "Ridge Regression", 0.964 , 0.870, 3588613.77 ])
table2.add_row([3, "Lasso Regression", 0.964 , 0.854, 4046019.36 ])
table2.add_row([4, "Polynomial SVR", -0.128 , 0.00029, 27800504.99 ])
print('Accuracy of models after removing less important features')
print(table2)
# Out:
# Accuracy of models with all features
# +--------+-------------------+----------------+---------------+------------+
# | Sr.No. |       Model       | Train accuracy | Test accuracy |    MSE     |
# +--------+-------------------+----------------+---------------+------------+
# |   1    | Linear Regression |     0.974      |   -2.005e+23  |  5.57e+30  |
# +--------+-------------------+----------------+---------------+------------+
# |   2    |  Ridge Regression |     0.972      |     0.883     | 3250996.36 |
# +--------+-------------------+----------------+---------------+------------+
# |   3    |  Lasso Regression |     0.974      |     0.822     | 4948475.08 |
# +--------+-------------------+----------------+---------------+------------+
# |   4    |   Polynomial SVR  |     -0.12      |    0.00049    | 27794961.6 |
# +--------+-------------------+----------------+---------------+------------+
# Accuracy of models after removing less important features
# +--------+-------------------+----------------+---------------+-------------+
# | Sr.No. |       Model       | Train accuracy | Test accuracy |     MSE     |
# +--------+-------------------+----------------+---------------+-------------+
# |   1    | Linear Regression |     0.964      |     0.871     |  3570110.94 |
# +--------+-------------------+----------------+---------------+-------------+
# |   2    |  Ridge Regression |     0.964      |      0.87     |  3588613.77 |
# +--------+-------------------+----------------+---------------+-------------+
# |   3    |  Lasso Regression |     0.964      |     0.854     |  4046019.36 |
# +--------+-------------------+----------------+---------------+-------------+
# |   4    |   Polynomial SVR  |     -0.128     |    0.00029    | 27800504.99 |
# +--------+-------------------+----------------+---------------+-------------+

# %% [markdown]
# After comparing both Ridge Regression model we can see only 1.13% accuracy difference. Hence We can use 2nd Ridge Regression model (model trained on data after removing less important features).
#
# We have trained models on train set and checked it's accuracy on test set and we have got best model.

# %% [markdown]
# # Let's check accuracy of selected model for all dataset using cross validation

# %%
# standardize all dataset
scaler = StandardScaler()
std_X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(Ridge(), std_X, y, cv=cv)
# Out:
# array([0.8604188 , 0.94006844, 0.94474269, 0.91123001, 0.88795189])

# %% [markdown]
# Average accuracy of cross validation models is 90 %, which is very good.
#
# ## Finally we can use Ridge Regression model as a final model for price prediction.

# %% [markdown]
# ## Build pipeline for price prediction

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
Input=[('scale',StandardScaler()), ('model',Ridge())]

# %%
pipe=Pipeline(Input)
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()), ('model', Ridge())])

# %%
pipe.fit(X, y)
print('train accuracy : ',pipe.score(X, y))
# Out:
# train accuracy :  0.9580734059346432

# %% [markdown]
# # Price prediction function

# %%
def predict_price(wheel_base, width,engine_size, bore,horsepower,highway_mpg,make,fuel,aspiration,
                  body_style,drive_wheels,engine_location,num_of_cylinders,fuel_system):    
    loc_index = np.where(X.columns==make)[0][0]
    loc_index = np.where(X.columns==fuel)[0][0]
    loc_index = np.where(X.columns==aspiration)[0][0]
    loc_index = np.where(X.columns==body_style)[0][0]
    loc_index = np.where(X.columns==drive_wheels)[0][0]
    loc_index = np.where(X.columns==engine_location)[0][0]
    loc_index = np.where(X.columns==num_of_cylinders)[0][0]
    loc_index = np.where(X.columns==fuel_system)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = wheel_base
    x[1] = width
    x[2] = engine_size
    x[3] = bore
    x[4] = horsepower
    x[5] = highway_mpg
    if loc_index >= 0:
        x[loc_index] = 1

    return pipe.predict([x])[0]

# %%
predict_price(90, 80,150, 3.50,120,25,'make_saab','fuel-type_gas','aspiration_std','body-style_sedan','drive-wheels_fwd','engine-location_front',
       'num-of-cylinders_four','fuel-system_4bbl')
# Out:
# 28788.014498742523

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Comparing these four models, we conclude that the Ridge Regression model is the best model to be able to predict price from our dataset.
